# %%
import pandas as pd
import numpy as np

results = pd.read_csv('/Users/veronica/Desktop/results.csv')
results
# Out:
#      k   l         S        DB         I
# 0    2  18  0.675245  1.352044  0.388349
# 1    3  18 -0.054515  2.447569  1.218996
# 2    4  18  0.015627  2.067782  0.703055
# 3    5  18  0.154931  2.187371  0.243251
# 4    6  18  0.201467  1.766292  0.080024
# 5    7  18  0.023891  2.313511  0.053076
# 6    8  18  0.133385  2.114063  0.151892
# 7    9  18 -0.149548  2.165245  0.275960
# 8   10  18  0.071632  1.839693  0.041317
# 9   11  18 -0.163775  2.369326  0.115206
# 10  12  18 -0.158457  2.938808  0.078172
# 11  13  18  0.109446  2.213057  0.045991
# 12  14  18 -0.101822  2.767542  0.049607
# 13  15  18 -0.112987  2.216893  0.025048
# 14  16  18 -0.143495  2.774618  0.022817
# 15  17  18 -0.086478  2.500317  0.028669
# 16  18  18 -0.022853  2.619151  0.034104
# 17  19  18 -0.014366  2.164804  0.026894
# 18  20  18 -0.050721  2.256380  0.034184
# 19  21  18 -0.034879  2.209744  0.020889
# 20  22  18 -0.252527  2.502044  0.060007
# 21  23  18  0.038859  2.372021  0.014807
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

cmap = cm.get_cmap('cool')

df = results.copy()

df['Inverted Davies-Bouldin score'] = df['DB'].apply(lambda x: 1/x)
df['Silhouette score'] = df['S']
df['I Index'] = df['I']

df.plot(x='k', y=['Silhouette score', 'I Index', 'Inverted Davies-Bouldin score'],
        kind='line', figsize=(10, 7), xlabel='number of clusters $k$', ylabel='score of metric', 
        cmap=cmap, xticks=[x for x in range(0, 50, 2)], title='metric scores depending on number of clusters $k$')
 
# display plot
plt.show()

# значения метрик в зависимости от количества кластеров
# датасет 3-грамм с 155.243 уникальными векторами, l = 18

# %%
[x for x in range(0, 50, 2)]

# %%
results1 = pd.read_csv('/Users/veronica/Desktop/results1.csv')
results1
# Out:
#     k   l         S        DB         I
# 0   2   2  0.067951  2.299776  0.188392
# 1   2   5 -0.183755  3.868786  1.726010
# 2   2   8 -0.315125  3.379084  4.368927
# 3   2  11  0.126325  2.290728  0.692396
# 4   2  14  0.465627  1.690979  0.126531
# 5   2  17  0.196476  2.473719  1.026695
# 6   4   2 -0.171678  6.542474  0.030477
# 7   4   5 -0.129927  3.792926  0.077443
# 8   4   8 -0.224710  3.042241  0.579549
# 9   4  11 -0.137970  3.668372  0.107877
# 10  4  14 -0.193126  2.767948  1.888966
# 11  4  17  0.018296  2.327547  0.737856

# %%
results2 = pd.read_csv('/Users/veronica/Desktop/results2.csv')
results2
# Out:
#     k   l         S         DB         I
# 0   6   2 -0.299843   5.050915  0.070030
# 1   6   5 -0.187379   3.022392  0.039846
# 2   6   8 -0.056640   5.153969  0.044558
# 3   6  11 -0.222334   7.769383  0.082549
# 4   6  14 -0.137044   2.741396  0.147977
# 5   6  17 -0.055654   2.486282  0.074140
# 6   8   2 -0.221465  35.758834  0.015356
# 7   8   5 -0.252641   6.076799  0.024462
# 8   8   8 -0.286941   5.723802  0.069063
# 9   8  11 -0.227865   4.247535  0.164159
# 10  8  14 -0.087696   2.981276  0.020728
# 11  8  17 -0.163928   3.157463  0.108482

# %%
results3 = pd.read_csv('/Users/veronica/Desktop/results3.csv')
results3
# Out:
#      k   l         S         DB         I
# 0   10   2 -0.269277  16.551955  0.009486
# 1   10   5 -0.185264   8.483188  0.005142
# 2   10   8 -0.171392   6.072319  0.003246
# 3   10  11 -0.243032   4.967335  0.064635
# 4   10  14 -0.101689   3.919937  0.025090
# 5   10  17 -0.190473   2.523898  0.047275
# 6   12   2 -0.258138  17.466702  0.007004
# 7   12   5 -0.248604   8.357447  0.007015
# 8   12   8 -0.346496   6.404149  0.003182
# 9   12  11 -0.288614   4.052770  0.039179
# 10  12  14 -0.206298   3.514299  0.058200
# 11  12  17 -0.171657   2.651813  0.053187
# 12  14   2 -0.239930  28.523167  0.010903
# 13  14   5 -0.316961   8.990052  0.002061
# 14  14   8 -0.181930  10.313731  0.003210
# 15  14  11 -0.249834   4.613111  0.011473
# 16  14  14 -0.220156   3.693442  0.015921
# 17  14  17 -0.159454   2.247617  0.030223

# %%
results4 = pd.read_csv('/Users/veronica/Desktop/results4.csv')
results4
# Out:
#      k   l         S         DB         I
# 0   16   2 -0.249077  17.201414  0.006545
# 1   16   5 -0.218199   7.933639  0.001271
# 2   16   8 -0.203777   5.521294  0.003081
# 3   16  11 -0.206404   5.061405  0.010923
# 4   16  14 -0.196115   3.156664  0.009914
# 5   16  17 -0.204339   2.646684  0.036410
# 6   18   2 -0.239491  25.025299  0.003020
# 7   18   5 -0.207526  12.006748  0.002896
# 8   18   8 -0.342451  10.057097  0.001802
# 9   18  11 -0.302570   5.506552  0.013262
# 10  18  14 -0.235931   3.875473  0.012886
# 11  18  17 -0.180628   2.886474  0.013706

# %%
results5 = pd.read_csv('/Users/veronica/Desktop/results5.csv')
results5
# Out:
#      k   l         S         DB         I
# 0   20   2 -0.210122  22.101493  0.004610
# 1   20   5 -0.332238   9.810104  0.000449
# 2   20   8 -0.249725   5.049895  0.006473
# 3   20  11 -0.322984   5.555398  0.008817
# 4   20  14 -0.066690   3.619756  0.020635
# 5   20  17 -0.242716   2.224118  0.026840
# 6   22   2 -0.248068  18.702949  0.007716
# 7   22   5 -0.288181  11.939578  0.001915
# 8   22   8 -0.324883   7.725994  0.008472
# 9   22  11 -0.310843   4.843536  0.011471
# 10  22  14 -0.247969   3.720436  0.010544
# 11  22  17 -0.197671   2.940599  0.011532
# 12  24   2 -0.247833  34.093988  0.002471
# 13  24   5 -0.305251  11.733621  0.000709
# 14  24   8 -0.365499   6.302540  0.000958
# 15  24  11 -0.295415   4.646789  0.011309
# 16  24  14 -0.218724   4.262034  0.007607
# 17  24  17 -0.172925   3.636994  0.009448

# %%
results6 = pd.read_csv('/Users/veronica/Desktop/results6.csv')
results6
# Out:
#      k   l         S         DB         I
# 0   26   2 -0.245259  20.181456  0.002253
# 1   26   5 -0.357506  10.650100  0.001383
# 2   26   8 -0.283316   9.038617  0.004352
# 3   26  11 -0.375197   5.683716  0.010031
# 4   26  14 -0.275080   3.807428  0.004773
# 5   26  17 -0.199625   2.911007  0.007914
# 6   28   2 -0.231533  30.545192  0.001834
# 7   28   5 -0.321526  12.413071  0.000691
# 8   28   8 -0.436791  10.529629  0.001895
# 9   28  11 -0.347814   5.404146  0.004738
# 10  28  14 -0.254369   3.258237  0.009625
# 11  28  17 -0.337833   2.770806  0.007673

# %%
results7 = pd.read_csv('/Users/veronica/Desktop/results7.csv')
results7
# Out:
#      k   l         S         DB         I
# 0   30   2 -0.268084  27.913028  0.002698
# 1   30   5 -0.308794  14.331218  0.001022
# 2   30   8 -0.379153   9.772968  0.000928
# 3   30  11 -0.290594   5.175884  0.004772
# 4   30  14 -0.262862   3.980610  0.014061
# 5   30  17 -0.179035   2.548766  0.006355
# 6   32   2 -0.242788  26.888995  0.001086
# 7   32   5 -0.334977  10.379809  0.000685
# 8   32   8 -0.396122   9.921678  0.000263
# 9   32  11 -0.388380   5.557452  0.003235
# 10  32  14 -0.253536   3.826136  0.007808
# 11  32  17 -0.322050   3.333884  0.004506
# 12  34   2 -0.255653  25.248009  0.000861
# 13  34   5 -0.260494  10.912389  0.000633
# 14  34   8 -0.358023   8.377614  0.000607
# 15  34  11 -0.390224   6.146995  0.006280
# 16  34  14 -0.222639   3.664812  0.004348
# 17  34  17 -0.340595   3.278551  0.006774

# %%
results8 = pd.read_csv('/Users/veronica/Desktop/results8.csv')
results8
# Out:
#      k   l         S         DB         I
# 0   36   2 -0.253260  32.535104  0.001112
# 1   36   5 -0.294923  10.325310  0.001258
# 2   36   8 -0.384518   7.389464  0.000607
# 3   36  11 -0.281674   6.168552  0.003228
# 4   36  14 -0.319233   4.487442  0.006119
# 5   36  17 -0.189691   2.980111  0.003884
# 6   38   2 -0.203933  26.649936  0.000975
# 7   38   5 -0.281873  10.460295  0.001184
# 8   38   8 -0.356499   7.609277  0.001649
# 9   38  11 -0.351135   6.454307  0.004818
# 10  38  14 -0.309263   4.448485  0.007714
# 11  38  17 -0.210138   3.054461  0.002956

# %%
results9 = pd.read_csv('/Users/veronica/Desktop/results9.csv')
results9
# Out:
#      k   l         S         DB         I
# 0   40   2 -0.255454  33.750733  0.000951
# 1   40   5 -0.378672  12.799756  0.000483
# 2   40   8 -0.427304   9.245574  0.000585
# 3   40  11 -0.391236   7.282271  0.003930
# 4   40  14 -0.228230   4.233896  0.003596
# 5   40  17 -0.261938   3.550926  0.003579
# 6   42   2 -0.275550  25.175863  0.000931
# 7   42   5 -0.280153   9.971624  0.000807
# 8   42   8 -0.326311   8.151760  0.002378
# 9   42  11 -0.339717   5.581130  0.003366
# 10  42  14 -0.303114   4.186087  0.004466
# 11  42  17 -0.324216   2.985008  0.004272
# 12  44   2 -0.217958  25.094862  0.000661
# 13  44   5 -0.302310  13.476139  0.000690
# 14  44   8 -0.345032   7.501913  0.002134
# 15  44  11 -0.350701   4.874302  0.003939
# 16  44  14 -0.221311   4.950679  0.002104
# 17  44  17 -0.280989   2.978415  0.006284

# %%
results10 = pd.read_csv('/Users/veronica/Desktop/results10.csv')
results10
# Out:
#      k   l         S         DB         I
# 0   46   2 -0.220418  26.254822  0.000568
# 1   46   5 -0.336941  11.137381  0.000672
# 2   46   8 -0.392911  10.178146  0.001565
# 3   46  11 -0.353060   6.664277  0.003257
# 4   46  14 -0.370178   4.166483  0.003632
# 5   46  17 -0.317254   3.429370  0.003286
# 6   48   2 -0.249931  27.469240  0.000591
# 7   48   5 -0.327750  12.042857  0.000269
# 8   48   8 -0.439937   9.462820  0.001401
# 9   48  11 -0.393809   6.003939  0.001680
# 10  48  14 -0.278666   3.939697  0.005072
# 11  48  17 -0.293416   3.091501  0.003310
# 12  50   2 -0.287176  29.624097  0.000621
# 13  50   5 -0.374449  11.112580  0.000294
# 14  50   8 -0.352711   6.916051  0.000955
# 15  50  11 -0.341645   5.183725  0.002003
# 16  50  14 -0.285891   4.594828  0.002742
# 17  50  17 -0.274964   3.288663  0.002068

# %%
results1_10 = pd.concat([results1, results2, results3, results4, results5, results6, results7, results8, results9, results10], ignore_index=True, sort=False)
results1_10
# Out:
#       k   l         S         DB         I
# 0     2   2  0.067951   2.299776  0.188392
# 1     2   5 -0.183755   3.868786  1.726010
# 2     2   8 -0.315125   3.379084  4.368927
# 3     2  11  0.126325   2.290728  0.692396
# 4     2  14  0.465627   1.690979  0.126531
# ..   ..  ..       ...        ...       ...
# 145  50   5 -0.374449  11.112580  0.000294
# 146  50   8 -0.352711   6.916051  0.000955
# 147  50  11 -0.341645   5.183725  0.002003
# 148  50  14 -0.285891   4.594828  0.002742
# 149  50  17 -0.274964   3.288663  0.002068
#
# [150 rows x 5 columns]

# %%
results_l1 = pd.read_csv('/Users/veronica/Desktop/results_l1.csv')
results_l1
# Out:
#     k  l         S         DB         I
# 0  15  2 -0.194421  32.344665  0.002385
# 1  15  3 -0.234106  12.184834  0.003849
# 2  15  4 -0.253876  16.245249  0.002491
# 3  15  5 -0.257193  11.662641  0.002758

# %%
results_l2 = pd.read_csv('/Users/veronica/Desktop/results_l2.csv')
results_l2
# Out:
#     k  l         S         DB         I
# 0  15  6 -0.344857  10.187760  0.010265
# 1  15  7 -0.283125   8.748916  0.003988
# 2  15  8 -0.179084   9.564489  0.011586
# 3  15  9 -0.299809   7.007421  0.005369

# %%
results_l3 = pd.read_csv('/Users/veronica/Desktop/results_l3.csv')
results_l3
# Out:
#     k   l         S        DB         I
# 0  15  10 -0.350995  5.136500  0.020476
# 1  15  11 -0.221681  4.566928  0.008182
# 2  15  12 -0.264005  3.947176  0.016265
# 3  15  13 -0.269494  4.590134  0.040610

# %%
results_l4 = pd.read_csv('/Users/veronica/Desktop/results_l4.csv')
results_l4
# Out:
#     k   l         S        DB         I
# 0  15  14 -0.267622  3.875718  0.006013
# 1  15  15 -0.220133  3.401086  0.023907
# 2  15  16 -0.166127  3.036149  0.016156
# 3  15  17 -0.152530  3.292025  0.016995
# 4  15  18 -0.062685  2.378514  0.059782

# %%
results_k15 = pd.concat([results_l1, results_l2, results_l3, results_l4], ignore_index=True, sort=False)
results_k15
# Out:
#      k   l         S         DB         I
# 0   15   2 -0.194421  32.344665  0.002385
# 1   15   3 -0.234106  12.184834  0.003849
# 2   15   4 -0.253876  16.245249  0.002491
# 3   15   5 -0.257193  11.662641  0.002758
# 4   15   6 -0.344857  10.187760  0.010265
# 5   15   7 -0.283125   8.748916  0.003988
# 6   15   8 -0.179084   9.564489  0.011586
# 7   15   9 -0.299809   7.007421  0.005369
# 8   15  10 -0.350995   5.136500  0.020476
# 9   15  11 -0.221681   4.566928  0.008182
# 10  15  12 -0.264005   3.947176  0.016265
# 11  15  13 -0.269494   4.590134  0.040610
# 12  15  14 -0.267622   3.875718  0.006013
# 13  15  15 -0.220133   3.401086  0.023907
# 14  15  16 -0.166127   3.036149  0.016156
# 15  15  17 -0.152530   3.292025  0.016995
# 16  15  18 -0.062685   2.378514  0.059782

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

cmap = cm.get_cmap('cool')

df = results_k15.copy()

df['Inverted Davies-Bouldin score'] = df['DB'].apply(lambda x: 1/x)
df['Silhouette score'] = df['S']
df['I Index'] = df['I']
df['average size of cluster\'s subspace $l$'] = df['l']

df.plot(x='average size of cluster\'s subspace $l$', y=['Silhouette score', 'I Index', 'Inverted Davies-Bouldin score'],
        kind='line', figsize=(10, 7), ylabel='score of metric', cmap=cmap, xticks=df.l, 
        title='metric scores depending on average size of cluster\'s subspace $l$')
 
# display plot
plt.show()

# %%
results1_10
# Out:
#       k   l         S         DB         I
# 0     2   2  0.067951   2.299776  0.188392
# 1     2   5 -0.183755   3.868786  1.726010
# 2     2   8 -0.315125   3.379084  4.368927
# 3     2  11  0.126325   2.290728  0.692396
# 4     2  14  0.465627   1.690979  0.126531
# ..   ..  ..       ...        ...       ...
# 145  50   5 -0.374449  11.112580  0.000294
# 146  50   8 -0.352711   6.916051  0.000955
# 147  50  11 -0.341645   5.183725  0.002003
# 148  50  14 -0.285891   4.594828  0.002742
# 149  50  17 -0.274964   3.288663  0.002068
#
# [150 rows x 5 columns]

# %%
# results1_10 - кластеризация для k от 2 до 50, для каждого k - средний размер подпространства кластера l от 2 до 18

# %%
# голосование большинства метрик для каждого k от 2 до 50 -> составление df_best

df_best = pd.DataFrame()

for k in range(2, 51, 2):
    
    df_k = results1_10[results1_10['k'] == k]
    df_k = df_k.reset_index(drop=True)

    votes = [0 for x in range(len(df_k))]

    I_max_win = int(df_k[df_k.I == df_k.I.max()].index[0])
    S_max_win = int(df_k[df_k.S == df_k.S.max()].index[0])
    DB_min_win = int(df_k[df_k.DB == df_k.DB.min()].index[0])

    votes[I_max_win] += 1
    votes[S_max_win] += 1
    votes[DB_min_win] += 1
    
    wins = [I_max_win, S_max_win, DB_min_win]
    
    if len(wins) == len(set(wins)):
        print("hmm, which one? ", k)

    win_index = max(range(len(votes)), key=votes.__getitem__)

    df_best = pd.concat([df_best, df_k.iloc[[win_index]]], ignore_index=True, sort=False)
# Out:
# hmm, which one?  10
# hmm, which one?  28
# hmm, which one?  32
# hmm, which one?  38
# hmm, which one?  40
# hmm, which one?  42
# hmm, which one?  46
# hmm, which one?  48

# %%
df_k = results1_10[results1_10['k'] == 48]
df_k = df_k.reset_index(drop=True)

votes = [0 for x in range(len(df_k))]

I_max_win = int(df_k[df_k.I == df_k.I.max()].index[0])
S_max_win = int(df_k[df_k.S == df_k.S.max()].index[0])
DB_min_win = int(df_k[df_k.DB == df_k.DB.min()].index[0])

print(df_k)
print()
print(I_max_win, S_max_win, DB_min_win)
# Out:
#     k   l         S         DB         I
# 0  48   2 -0.249931  27.469240  0.000591
# 1  48   5 -0.327750  12.042857  0.000269
# 2  48   8 -0.439937   9.462820  0.001401
# 3  48  11 -0.393809   6.003939  0.001680
# 4  48  14 -0.278666   3.939697  0.005072
# 5  48  17 -0.293416   3.091501  0.003310
#
# 4 0 5

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

cmap = cm.get_cmap('cool')

df = df_best.copy()

df['Inverted Davies-Bouldin score'] = df['DB'].apply(lambda x: 1/x)
df['Silhouette score'] = df['S']
df['I Index'] = df['I']

df.plot(x='k', y=['Silhouette score', 'I Index', 'Inverted Davies-Bouldin score'],
        kind='line', figsize=(10, 7), ylabel='score of metric', xlabel='number of clusters k', 
        cmap=cmap, xticks=df.k)
 
# display plot
plt.show()

# %%
import random

# голосование большинства метрик для каждого k от 2 до 50 -> составление df_best
# если все три проголосовали по-разному - берем рандомный из трех выбранных

df_best = pd.DataFrame()

for k in range(2, 51, 2):
    
    df_k = results1_10[results1_10['k'] == k]
    df_k = df_k.reset_index(drop=True)

    votes = [0 for x in range(len(df_k))]

    I_max_win = int(df_k[df_k.I == df_k.I.max()].index[0])
    S_max_win = int(df_k[df_k.S == df_k.S.max()].index[0])
    DB_min_win = int(df_k[df_k.DB == df_k.DB.min()].index[0])

    votes[I_max_win] += 1
    votes[S_max_win] += 1
    votes[DB_min_win] += 1
    
    wins = [I_max_win, S_max_win, DB_min_win]
    
    if len(wins) == len(set(wins)):
        win_index = random.choice(wins)
    else:
        win_index = max(range(len(votes)), key=votes.__getitem__)

    df_best = pd.concat([df_best, df_k.iloc[[win_index]]], ignore_index=True, sort=False)

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

cmap = cm.get_cmap('cool')

df = df_best.copy()

df['Inverted Davies-Bouldin score'] = df['DB'].apply(lambda x: 1/x)
df['Silhouette score'] = df['S']
df['I Index'] = df['I']

df.plot(x='k', y=['Silhouette score', 'I Index', 'Inverted Davies-Bouldin score'],
        kind='line', figsize=(10, 7), ylabel='score of metric', xlabel='number of clusters k', 
        cmap=cmap, xticks=df.k)
 
# display plot
plt.show()

# %% [markdown]
# I Index

# %%
df_best[df_best.I == df_best.I.max()]
# Out:
#    k   l         S        DB         I
# 1  4  17  0.018296  2.327547  0.737856

# %% [markdown]
# Silhouette score

# %%
df_best[df_best.S == df_best.S.max()]
# Out:
#    k   l         S        DB         I
# 0  2  14  0.465627  1.690979  0.126531

# %% [markdown]
# Davies-Bouldin score

# %%
df_best[df_best.DB == df_best.DB.min()]
# Out:
#    k   l         S        DB         I
# 0  2  14  0.465627  1.690979  0.126531

# %%
# если убрать k = 2 -> DB выберет k = 20, S выберет k = 4

df_best_2 = df_best.copy()
df_best_2 = df_best_2[df_best_2.k != 2]

# %%
df_best_2[df_best_2.S == df_best_2.S.max()]
# Out:
#    k   l         S        DB         I
# 1  4  17  0.018296  2.327547  0.737856

# %%
df_best_2[df_best_2.DB == df_best_2.DB.min()]
# Out:
#     k   l         S        DB        I
# 9  20  17 -0.242716  2.224118  0.02684

# %%
# если убрать k = 4 -> S выберет k = 6, I выберет k = 6

df_best_3 = df_best_2.copy()
df_best_3 = df_best_3[df_best_3.k != 4]

# %%
df_best_3[df_best_3.S == df_best_3.S.max()]
# Out:
#    k   l         S        DB        I
# 2  6  17 -0.055654  2.486282  0.07414

# %%
df_best_3[df_best_3.I == df_best_3.I.max()]
# Out:
#    k   l         S        DB        I
# 2  6  17 -0.055654  2.486282  0.07414

# %%
D = np.load('/Users/veronica/Desktop/dimentions_k20_l17.npy', allow_pickle=True)
A = np.load('/Users/veronica/Desktop/assigns_k20_l17.npy', allow_pickle=True)
M = np.load('/Users/veronica/Desktop/medoids_k20_l17.npy', allow_pickle=True)
X = np.load('/Users/veronica/Desktop/datasetRU_k6n3_even_512.npy', allow_pickle=True)
X = np.unique(X, axis=0)

# %%
len(A)
# Out:
# 155243

# %%
len(X[0])
# Out:
# 18

# %%
k 15 l 8 (силуэт)

# %%
k 4 l 17 (I best)

# %%
k 2 l 14 (силуэт best)

# %%
k 6 l 17

# %%
import pandas as pd
import numpy as np

# %%
results11 = pd.read_csv('/Users/veronica/Desktop/results11.csv')
results12 = pd.read_csv('/Users/veronica/Desktop/results12.csv')
results13 = pd.read_csv('/Users/veronica/Desktop/results13.csv')
results14 = pd.read_csv('/Users/veronica/Desktop/results14.csv')
results15 = pd.read_csv('/Users/veronica/Desktop/results15.csv')
results16 = pd.read_csv('/Users/veronica/Desktop/results16.csv')
results17 = pd.read_csv('/Users/veronica/Desktop/results17.csv')
results18 = pd.read_csv('/Users/veronica/Desktop/results18.csv')
results19 = pd.read_csv('/Users/veronica/Desktop/results19.csv')
results20 = pd.read_csv('/Users/veronica/Desktop/results20.csv')

# %%
results11_20 = pd.concat([results11, results12, results13, results14, results15, results16, results17, results18, results19, results20], ignore_index=True, sort=False)
results11_20
# Out:
#        k   l         S         DB         I
# 0     51   2 -0.297962  29.546774  0.000731
# 1     51   5 -0.363276  13.609477  0.000247
# 2     51   8 -0.368665   9.658027  0.001363
# 3     51  11 -0.324587   5.286965  0.001789
# 4     51  14 -0.280305   4.458517  0.001904
# ..   ...  ..       ...        ...       ...
# 169  100   5 -0.341403  11.887527  0.000180
# 170  100   8 -0.428767   9.177285  0.000094
# 171  100  11 -0.464567   6.484175  0.000387
# 172  100  14 -0.301888   3.748314  0.001127
# 173  100  17 -0.278320   3.090683  0.001444
#
# [174 rows x 5 columns]

# %%
# results11_20 - кластеризация для k от 51 до 100, для каждого k - средний размер подпространства кластера l от 2 до 18

# %%
a1 = [x for x in range(51, 56, 2)]
a2 = [x for x in range(56, 60, 2)]
a3 = [x for x in range(61, 66, 2)]
a4 = [x for x in range(66, 71, 2)]
a5 = [x for x in range(71, 76, 2)]
a6 = [x for x in range(76, 81, 2)]
a7 = [x for x in range(81, 86, 2)]
a8 = [x for x in range(86, 91, 2)]
a9 = [x for x in range(91, 96, 2)]
a10 = [x for x in range(96, 101, 2)]

a = a1 + a2 + a3 + a4 + a5 + a6 + a7 + a8 + a9 + a10

# %%
import random

# голосование большинства метрик для каждого k от 51 до 100 -> составление df_best
# если все три проголосовали по-разному - берем рандомный из трех выбранных

df_best = pd.DataFrame()

for k in a:
    
    df_k = results11_20[results11_20['k'] == k]
    df_k = df_k.reset_index(drop=True)

    votes = [0 for x in range(len(df_k))]
    I_max_win = int(df_k[df_k.I == df_k.I.max()].index[0])
    S_max_win = int(df_k[df_k.S == df_k.S.max()].index[0])
    DB_min_win = int(df_k[df_k.DB == df_k.DB.min()].index[0])

    votes[I_max_win] += 1
    votes[S_max_win] += 1
    votes[DB_min_win] += 1
    
    wins = [I_max_win, S_max_win, DB_min_win]
    
    if len(wins) == len(set(wins)):
        win_index = random.choice(wins)
    else:
        win_index = max(range(len(votes)), key=votes.__getitem__)

    df_best = pd.concat([df_best, df_k.iloc[[win_index]]], ignore_index=True, sort=False)

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

cmap = cm.get_cmap('cool')

df = df_best.copy()

df['Inverted Davies-Bouldin score'] = df['DB'].apply(lambda x: 1/x)
df['Silhouette score'] = df['S']
df['I Index'] = df['I']

df.plot(x='k', y=['Silhouette score', 'I Index', 'Inverted Davies-Bouldin score'],
        kind='line', figsize=(10, 7), ylabel='score of metric', xlabel='number of clusters k', 
        cmap=cmap, xticks=df.k)
 
# display plot
plt.show()

# %% [markdown]
# **Датасет ботов**

# %%
bot_results1 = pd.read_csv('/Users/veronica/Desktop/bot_results/results1.csv')
bot_results2 = pd.read_csv('/Users/veronica/Desktop/bot_results/results2.csv')
bot_results3 = pd.read_csv('/Users/veronica/Desktop/bot_results/results3.csv')
bot_results4 = pd.read_csv('/Users/veronica/Desktop/bot_results/results4.csv')
bot_results5 = pd.read_csv('/Users/veronica/Desktop/bot_results/results5.csv')
bot_results6 = pd.read_csv('/Users/veronica/Desktop/bot_results/results6.csv')
bot_results7 = pd.read_csv('/Users/veronica/Desktop/bot_results/results7.csv')
bot_results8 = pd.read_csv('/Users/veronica/Desktop/bot_results/results8.csv')
bot_results9 = pd.read_csv('/Users/veronica/Desktop/bot_results/results9.csv')
bot_results10 = pd.read_csv('/Users/veronica/Desktop/bot_results/results10.csv')

bot_results1_10 = pd.concat([bot_results1, bot_results2, bot_results3, bot_results4, bot_results5, bot_results6, bot_results7, bot_results8, bot_results9, bot_results10], ignore_index=True, sort=False)
bot_results1_10
# Out:
#       k   l         S        DB         I
# 0     2   2  0.040720  9.778371  0.092474
# 1     2   5  0.003750  2.691984  0.190936
# 2     2   8  0.096814  2.694011  0.192189
# 3     2  11  0.393331  2.023460  0.048591
# 4     2  14  0.443349  1.846631  0.207496
# ..   ..  ..       ...       ...       ...
# 145  50   5 -0.328107  6.151511  0.000414
# 146  50   8 -0.244417  5.502046  0.001436
# 147  50  11 -0.165237  4.719040  0.002547
# 148  50  14 -0.210581  3.732786  0.002461
# 149  50  17 -0.224659  3.094313  0.005474
#
# [150 rows x 5 columns]

# %%
import random

# голосование большинства метрик для каждого k от 2 до 50 -> составление df_best
# если все три проголосовали по-разному - берем рандомный из трех выбранных

df_best = pd.DataFrame()

for k in range(2, 51, 2):
    
    df_k = bot_results1_10[bot_results1_10['k'] == k]
    df_k = df_k.reset_index(drop=True)

    votes = [0 for x in range(len(df_k))]

    I_max_win = int(df_k[df_k.I == df_k.I.max()].index[0])
    S_max_win = int(df_k[df_k.S == df_k.S.max()].index[0])
    DB_min_win = int(df_k[df_k.DB == df_k.DB.min()].index[0])

    votes[I_max_win] += 1
    votes[S_max_win] += 1
    votes[DB_min_win] += 1
    
    wins = [I_max_win, S_max_win, DB_min_win]
    
    if len(wins) == len(set(wins)):
        win_index = random.choice(wins)
    else:
        win_index = max(range(len(votes)), key=votes.__getitem__)

    df_best = pd.concat([df_best, df_k.iloc[[win_index]]], ignore_index=True, sort=False)

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

cmap = cm.get_cmap('cool')

df = df_best.copy()

df['Inverted Davies-Bouldin score'] = df['DB'].apply(lambda x: 1/x)
df['Silhouette score'] = df['S']
df['I Index'] = df['I']

df.plot(x='k', y=['Silhouette score', 'I Index', 'Inverted Davies-Bouldin score'],
        kind='line', figsize=(10, 7), ylabel='score of metric', xlabel='number of clusters k', 
        cmap=cmap, xticks=df.k)
 
# display plot
plt.show()

# %% [markdown]
# I Index

# %%
bot_results1_10[bot_results1_10.I == bot_results1_10.I.max()]
# Out:
#    k   l         S        DB         I
# 5  2  17  0.073453  2.376476  0.483159

# %%
df_best[df_best.I == df_best.I.max()]
# Out:
#    k   l         S       DB         I
# 3  8  17 -0.165731  2.97724  0.249388

# %% [markdown]
# Silhouette score

# %%
bot_results1_10[bot_results1_10.S == bot_results1_10.S.max()]
# Out:
#    k   l         S        DB         I
# 4  2  14  0.443349  1.846631  0.207496

# %%
df_best[df_best.S == df_best.S.max()]
# Out:
#    k   l         S        DB         I
# 0  2  14  0.443349  1.846631  0.207496

# %% [markdown]
# Davies-Bouldin score

# %%
bot_results1_10[bot_results1_10.DB == bot_results1_10.DB.min()]
# Out:
#    k   l         S        DB         I
# 4  2  14  0.443349  1.846631  0.207496

# %%
df_best[df_best.DB == df_best.DB.min()]
# Out:
#    k   l         S        DB         I
# 0  2  14  0.443349  1.846631  0.207496
